# %%
from selenium import webdriver
driver = webdriver.Chrome()
url='https://new.land.naver.com/complexes/107439?ms=37.4841875,126.9615556,16&a=APT:ABYG:JGC:PRE&b=B1:A1&e=RETAIL&j=10&k=4'
driver.get(url)

# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# %%
box_element = driver.find_element(By.XPATH, '/html/body/div[2]/div/section/div[2]/div[1]/div/div[2]/div[2]/div')
# /html/body/div[2]/div/section/div[2]/div[1]/div/div[2]/div[2]/div
# /html/body/div[2]/div/section/div[2]/div[1]/div/div[2]/div[2]/div

# %%
box_element.text
# Out:
# '관악파크푸르지오 103동\n전세5억 8,000\n아파트111B/84m², 15/22층, 남향\n공동가능 공실 남향뷰 롯데타워뷰가 감동 붙박이장 팬트리 중문옵션\n아실 제공\n씨티공인중개사사무소\n확인24.01.03.네이버에서 보기\n관악파크푸르지오 103동\n전세6억\n아파트110C/84m², 10/22층, 남향\n33 신축급 남향 상태아주좋음 3베이선호구조 관악산전망 조용하고 깨끗한집\n부동산써브 제공\n관악파크푸르지오공인중개사사무소\n확인24.01.05.\n관악파크푸르지오 104동\n전세5억 7,000\n아파트110C/84m², 10/22층, 남향\n33 신축급 남향 확장형 3베이선호구조 햇볕잘드는집 조용, 상태아주좋은집\n매경부동산 제공\n관악파크푸르지오공인중개사사무소\n확인24.01.03.\n관악파크푸르지오 103동\n전세6억\n아파트110C/84m², 10/22층, 남향\n남향 로얄층. 최상의 조망 및 채광 통풍 좋음. 신축급 아파트 2호선 서\n부동산뱅크 제공\n낙성대공인중개사\n확인23.12.28.\n관악파크푸르지오 103동\n전세6억\n아파트110C/84m², 10/22층, 남향\n남향 관악산조망권 3bay 상태아주깨끗 강추\n부동산114 제공\n우진공인중개사사무소\n확인24.01.06.네이버에서 보기\n관악파크푸르지오 104동\n전세6억\n아파트110A/84m², 9/22층, 동향\n3월중 입주 협의, 확장형\n매경부동산 제공\n(단지내)서울e부동산중개사무소\n확인24.01.06.\n관악파크푸르지오 104동\n전세5억 8,000\n아파트110C/84m², 10/22층, 남동향\n강추 확장형 전망좋은 남향 2월말중 입주협의\n부동산써브 제공\n대성공인중개사사무소\n확인24.01.06.\n관악파크푸르지오 103동\n전세5억 8,000\n아파트111B/84m², 15/22층, 남향\n33 신축급 확장형 상태아주좋음 시원한 관악산전망 낙성대역10분\n부동산뱅크 제공\n관악파크푸르지오공인중개사사무소\n확인24.01.05.\n관악파크푸르지오 104동
# ...

# %%
box_element.text.split('.\n')
# Out:
# ['관악파크푸르지오 103동\n전세5억 8,000\n아파트111B/84m², 15/22층, 남향\n공동가능 공실 남향뷰 롯데타워뷰가 감동 붙박이장 팬트리 중문옵션\n아실 제공\n씨티공인중개사사무소\n확인24.01.03.네이버에서 보기\n관악파크푸르지오 103동\n전세6억\n아파트110C/84m², 10/22층, 남향\n33 신축급 남향 상태아주좋음 3베이선호구조 관악산전망 조용하고 깨끗한집\n부동산써브 제공\n관악파크푸르지오공인중개사사무소\n확인24.01.05',
#  '관악파크푸르지오 104동\n전세5억 7,000\n아파트110C/84m², 10/22층, 남향\n33 신축급 남향 확장형 3베이선호구조 햇볕잘드는집 조용, 상태아주좋은집\n매경부동산 제공\n관악파크푸르지오공인중개사사무소\n확인24.01.03',
#  '관악파크푸르지오 103동\n전세6억\n아파트110C/84m², 10/22층, 남향\n남향 로얄층. 최상의 조망 및 채광 통풍 좋음. 신축급 아파트 2호선 서\n부동산뱅크 제공\n낙성대공인중개사\n확인23.12.28',
#  '관악파크푸르지오 103동\n전세6억\n아파트110C/84m², 10/22층, 남향\n남향 관악산조망권 3bay 상태아주깨끗 강추\n부동산114 제공\n우진공인중개사사무소\n확인24.01.06.네이버에서 보기\n관악파크푸르지오 104동\n전세6억\n아파트110A/84m², 9/22층, 동향\n3월중 입주 협의, 확장형\n매경부동산 제공\n(단지내)서울e부동산중개사무소\n확인24.01.06',
#  '관악파크푸르지오 104동\n전세5억 8,000\n아파트110C/84m², 10/22층, 남동향\n강추 확장형 전망좋은 남향 2월말중 입주협의\n부동산써브 제공\n대성공인중개사사무소\n확인24.01.06',
# ...

# %%
result = box_element.text.split('.\n')

# %%
result[0]
# Out:
# '관악파크푸르지오 103동\n전세5억 8,000\n아파트111B/84m², 15/22층, 남향\n공동가능 공실 남향뷰 롯데타워뷰가 감동 붙박이장 팬트리 중문옵션\n아실 제공\n씨티공인중개사사무소\n확인24.01.03.네이버에서 보기\n관악파크푸르지오 103동\n전세6억\n아파트110C/84m², 10/22층, 남향\n33 신축급 남향 상태아주좋음 3베이선호구조 관악산전망 조용하고 깨끗한집\n부동산써브 제공\n관악파크푸르지오공인중개사사무소\n확인24.01.05'

# %%
result[1]
# Out:
# '관악파크푸르지오 104동\n전세5억 7,000\n아파트110C/84m², 10/22층, 남향\n33 신축급 남향 확장형 3베이선호구조 햇볕잘드는집 조용, 상태아주좋은집\n매경부동산 제공\n관악파크푸르지오공인중개사사무소\n확인24.01.03'

# %%
box_element.click()

# %%
box_element.send_keys(Keys.END)
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 box_element.send_keys(Keys.END)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webelement.py:230, in WebElement.send_keys(self, *value)
#     227             remote_files.append(self._upload(file))
#     228         value = "\n".join(remote_files)
# --> 230 self._execute(
#     231     Command.SEND_KEYS_TO_ELEMENT, {"text": "".join(keys_to_typing(value)), "value": keys_to_typing(value)}
#     232 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webelement.py:394, in WebElement._execute(self, command, params)
#     392     params = {}
#     393 params["id"] = self._id
# --> 394 return self._parent.execute(command, params)
#
# ...

# %%
from selenium.webdriver import ActionChains
action = ActionChains(driver)
action.context_click(box_element).perform()  # 우클릭

# %%
action.key_down(Keys.END,box_element).perform()

# %%
action.context_click(box_element)

# %%
box_element2 = driver.find_element(By.XPATH, '/html/body/div[2]/div/section/div[2]/div[1]/div/div[2]/div[2]/div')

# %%
len(box_element.text.split('\n'))
# Out:
# 560

# %%
len(box_element2.text.split('\n'))
# Out:
# 560

# %%
box_element.text
# Out:
# '관악파크푸르지오 103동\n전세5억 8,000\n아파트111B/84m², 15/22층, 남향\n공동가능 공실 남향뷰 롯데타워뷰가 감동 붙박이장 팬트리 중문옵션\n아실 제공\n씨티공인중개사사무소\n확인24.01.03.네이버에서 보기\n관악파크푸르지오 103동\n전세6억\n아파트110C/84m², 10/22층, 남향\n33 신축급 남향 상태아주좋음 3베이선호구조 관악산전망 조용하고 깨끗한집\n부동산써브 제공\n관악파크푸르지오공인중개사사무소\n확인24.01.05.\n관악파크푸르지오 104동\n전세5억 7,000\n아파트110C/84m², 10/22층, 남향\n33 신축급 남향 확장형 3베이선호구조 햇볕잘드는집 조용, 상태아주좋은집\n매경부동산 제공\n관악파크푸르지오공인중개사사무소\n확인24.01.03.\n관악파크푸르지오 103동\n전세6억\n아파트110C/84m², 10/22층, 남향\n남향 로얄층. 최상의 조망 및 채광 통풍 좋음. 신축급 아파트 2호선 서\n부동산뱅크 제공\n낙성대공인중개사\n확인23.12.28.\n관악파크푸르지오 104동\n전세6억\n아파트110A/84m², 9/22층, 동향\n3월중 입주 협의, 확장형\n매경부동산 제공\n(단지내)서울e부동산중개사무소\n확인24.01.06.\n관악파크푸르지오 104동\n전세5억 8,000\n아파트110C/84m², 10/22층, 남동향\n강추 확장형 전망좋은 남향 2월말중 입주협의\n부동산써브 제공\n대성공인중개사사무소\n확인24.01.06.\n관악파크푸르지오 103동\n전세6억\n아파트110C/84m², 10/22층, 남향\n남향 관악산조망권 3bay 상태아주깨끗 강추\n부동산114 제공\n우진공인중개사사무소\n확인24.01.06.네이버에서 보기\n관악파크푸르지오 102동\n매매9억 2,500\n아파트110A/84m², 2/21층, 동향\n확장형 숲세권, 시스템AC4대, 3년전 수리 . 입주협의. 가격조정\n부동산뱅크 제공\n월드공인중개사\n확인24.01.05.\n관악파크푸르지오 103동\n전세6억\n
# ...

# %%
box_element
